# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\nikhil.bandi\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Load the Dataset

# %%
fossils=pd.read_csv('train_data.csv') # loading the dataset

# %% [markdown]
# Features
#
#
# uranium_lead_ratio: Ratio of uranium to lead isotopes in the fossil sample.
#
# carbon_14_ratio: Ratio of carbon-14 isotopes present in the fossil sample.
#
# radioactive_decay_series: Measurement of the decay series from parent to daughter isotopes.
#
# stratigraphic_layer_depth: Depth of the fossil within the stratigraphic layer, in meters.
#
# isotopic_composition: Proportion of different isotopes within the fossil sample.
#
# fossil_size: Size of the fossil, in centimeters.
#
# fossil_weight: Weight of the fossil, in grams.
#
# geological_period: Geological period during which the fossil was formed.
#
# surrounding_rock_type: Type of rock surrounding the fossil.
#
# paleomagnetic_data: Paleomagnetic orientation data of the fossil site.
#
# stratigraphic_position: Position of the fossil within the stratigraphic column.
#
# age: Calculated age of the fossil based on various features, in years.

# %%
df=fossils.copy() # making a copy of the dataset so that analysis wont effect the original data.
df.head()
# Out:
#    uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0            0.738061         0.487707                  0.907884
# 1            0.560096         0.341738                  1.121302
# 2            0.424773         0.218493                  0.103855
# 3            0.349958         0.704649                  0.383617
# 4            0.886811         0.777494                  0.593254
#
#    stratigraphic_layer_depth geological_period paleomagnetic_data  \
# 0                      91.17        Cretaceous    Normal polarity
# 1                     165.44          Cambrian    Normal polarity
# 2                     218.98          Cambrian    Normal polarity
# 3                      51.09           Permian    Normal polarity
# 4                     313.72          Devonian    Normal polarity
#
#    inclusion_of_other_fossils  isotopic_composition surrounding_rock_type  \
# 0                       False              0.915951          Conglomerate
# 1                       False              0.803968             Limestone
# 2                        True              0.792441                 Shale
# 3                        True              0.074636             Limestone
# 4                        True              1.646640                 Shale
#
#   stratigraphic_position  fossil_size  fossil_weight    age
# 0                 Middle        50.65         432.00  43523
# 1                    Top        48.85         353.29  44112
# 2                 Bottom        37.66         371.33  43480
# 3                 Bottom        39.10         232.84  30228
# 4                    Top        90.84         277.67  67217

# %%
df.shape # checking the size of the dataset
# Out:
# (4398, 13)

# %%
df.info() # checking name of the column and datatype in it matches or not.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4398 entries, 0 to 4397
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   uranium_lead_ratio          4398 non-null   float64
#  1   carbon_14_ratio             4398 non-null   float64
#  2   radioactive_decay_series    4398 non-null   float64
#  3   stratigraphic_layer_depth   4398 non-null   float64
#  4   geological_period           4398 non-null   object
#  5   paleomagnetic_data          4398 non-null   object
#  6   inclusion_of_other_fossils  4398 non-null   bool
#  7   isotopic_composition        4398 non-null   float64
#  8   surrounding_rock_type       4398 non-null   object
#  9   stratigraphic_position      4398 non-null   object
#  10  fossil_size                 4398 non-null   float64
#  11  fossil_weight               4398 non-null   float64
#  12  age                         4398 non-null   int64
# dtypes: bool(1), float64(7), int64(1), object(4)
# memory usage: 416.7+ KB

# %%
df['age']=df['age'].values/1000

# %%
df.head()
# Out:
#    uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0            0.738061         0.487707                  0.907884
# 1            0.560096         0.341738                  1.121302
# 2            0.424773         0.218493                  0.103855
# 3            0.349958         0.704649                  0.383617
# 4            0.886811         0.777494                  0.593254
#
#    stratigraphic_layer_depth geological_period paleomagnetic_data  \
# 0                      91.17        Cretaceous    Normal polarity
# 1                     165.44          Cambrian    Normal polarity
# 2                     218.98          Cambrian    Normal polarity
# 3                      51.09           Permian    Normal polarity
# 4                     313.72          Devonian    Normal polarity
#
#    inclusion_of_other_fossils  isotopic_composition surrounding_rock_type  \
# 0                       False              0.915951          Conglomerate
# 1                       False              0.803968             Limestone
# 2                        True              0.792441                 Shale
# 3                        True              0.074636             Limestone
# 4                        True              1.646640                 Shale
#
#   stratigraphic_position  fossil_size  fossil_weight     age
# 0                 Middle        50.65         432.00  43.523
# 1                    Top        48.85         353.29  44.112
# 2                 Bottom        37.66         371.33  43.480
# 3                 Bottom        39.10         232.84  30.228
# 4                    Top        90.84         277.67  67.217

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4398 entries, 0 to 4397
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   uranium_lead_ratio          4398 non-null   float64
#  1   carbon_14_ratio             4398 non-null   float64
#  2   radioactive_decay_series    4398 non-null   float64
#  3   stratigraphic_layer_depth   4398 non-null   float64
#  4   geological_period           4398 non-null   object
#  5   paleomagnetic_data          4398 non-null   object
#  6   inclusion_of_other_fossils  4398 non-null   bool
#  7   isotopic_composition        4398 non-null   float64
#  8   surrounding_rock_type       4398 non-null   object
#  9   stratigraphic_position      4398 non-null   object
#  10  fossil_size                 4398 non-null   float64
#  11  fossil_weight               4398 non-null   float64
#  12  age                         4398 non-null   float64
# dtypes: bool(1), float64(8), object(4)
# memory usage: 416.7+ KB

# %%
df['inclusion_of_other_fossils']=df['inclusion_of_other_fossils'].astype(int)  # converting the boolean type column into
# integer so it is eaiser for the analysis.

# %%
df.isnull().sum() # checking the null values
# Out:
# uranium_lead_ratio            0
# carbon_14_ratio               0
# radioactive_decay_series      0
# stratigraphic_layer_depth     0
# geological_period             0
# paleomagnetic_data            0
# inclusion_of_other_fossils    0
# isotopic_composition          0
# surrounding_rock_type         0
# stratigraphic_position        0
# fossil_size                   0
# fossil_weight                 0
# age                           0
# dtype: int64

# %%
df.duplicated().sum() # checking any duplicates present in the dataset
# Out:
# 0

# %%
df_num=df.select_dtypes(include=np.number)
df_num.describe() 
# creating a dataframe of numeric values as df_numeric it makes eaiser for EDA.
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# count         4398.000000      4398.000000               4398.000000
# mean             0.486938         0.430116                  0.532054
# std              0.257132         0.233536                  0.287929
# min              0.000241         0.000244                  0.000076
# 25%              0.294091         0.246269                  0.316775
# 50%              0.473715         0.416046                  0.511830
# 75%              0.658012         0.590752                  0.723805
# max              1.533270         1.000000                  1.513325
#
#        stratigraphic_layer_depth  inclusion_of_other_fossils  \
# count                4398.000000                 4398.000000
# mean                  152.832801                    0.620055
# std                    86.272234                    0.485428
# min                     0.130000                    0.000000
# 25%                    85.390000                    0.000000
# 50%                   146.000000                    1.000000
# 75%                   211.932500                    1.000000
# max                   494.200000                    1.000000
#
#        isotopic_composition  fossil_size  fossil_weight          age
# count           4398.000000  4398.000000    4398.000000  4398.000000
# mean               0.938315    70.702460     326.655177    40.586656
# std                0.521643    37.352584     187.032333    15.200701
# min                0.000275     0.130000       0.620000     4.208000
# 25%                0.533519    42.487500     181.047500    29.766250
# 50%                0.905684    68.785000     308.260000    39.567000
# 75%                1.289307    96.440000     455.520000    50.550500
# max                3.071434   216.390000    1010.090000   103.079000

# %%
df_cat=df.select_dtypes(include=object)
df_cat.describe()
# creating new dataframe for categoric columns in the dataset.
# Out:
#        geological_period paleomagnetic_data surrounding_rock_type  \
# count               4398               4398                  4398
# unique                11                  2                     4
# top             Cambrian    Normal polarity             Sandstone
# freq                 882               3160                  1497
#
#        stratigraphic_position
# count                    4398
# unique                      3
# top                    Bottom
# freq                     2667

# %% [markdown]
# # Univariate Analysis

# %%
for i in df_cat.columns: # for every categorical column printing count of sub classes in the categorical columns.
    print(i)
    a=df_cat[i].value_counts()
    print(a)
# Out:
# geological_period
# Cambrian         882
# Triassic         676
# Cretaceous       601
# Devonian         498
# Jurassic         490
# Paleogene        405
# Permian          365
# Neogene          311
# Ordovician       100
# Carboniferous     52
# Silurian          18
# Name: geological_period, dtype: int64
# paleomagnetic_data
# Normal polarity      3160
# Reversed polarity    1238
# Name: paleomagnetic_data, dtype: int64
# surrounding_rock_type
# Sandstone       1497
# Limestone       1166
# Shale           1144
# Conglomerate     591
# Name: surrounding_rock_type, dtype: int64
# stratigraphic_position
# Bottom    2667
# Middle    1267
# Top        464
# Name: stratigraphic_position, dtype: int64

# %%
for i in df_num.columns:  # plotting box plot for every numeric column to know the data and outliers.
    sns.boxplot(df_num[i])
    plt.show()

# %%
for i in df_cat.columns:  # count plot for categorical column and how subclasses are spread.
    plt.figure(figsize=(12,6))
    sns.countplot(df_cat[i])
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
df
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0               0.738061         0.487707                  0.907884
# 1               0.560096         0.341738                  1.121302
# 2               0.424773         0.218493                  0.103855
# 3               0.349958         0.704649                  0.383617
# 4               0.886811         0.777494                  0.593254
# ...                  ...              ...                       ...
# 4393            0.049660         0.601750                  0.762490
# 4394            0.360085         0.215033                  1.002406
# 4395            0.464864         0.553313                  0.659639
# 4396            0.803338         0.272392                  0.123562
# 4397            0.321577         0.348233                  0.265161
#
#       stratigraphic_layer_depth geological_period paleomagnetic_data  \
# 0                         91.17        Cretaceous    Normal polarity
# 1                        165.44          Cambrian    Normal polarity
# 2                        218.98          Cambrian    Normal polarity
# 3                         51.09           Permian    Normal polarity
# 4                        313.72          Devonian    Normal polarity
# ...                         ...               ...                ...
# 4393                     222.54          Jurassic  Reversed polarity
# 4394                     276.70        Cretaceous  Reversed polarity
# 4395                      76.77          Devonian    Normal polarity
# 4396                     204.82           Neogene  Reversed polarity
# 4397                     436.61        Cretaceous    Normal polarity
#
#       inclusion_of_other_fossils  isotopic_composition surrounding_rock_type  \
# 0                              0              0.915951          Conglomerate
# 1                              0              0.803968             Limestone
# 2                              1              0.792441                 Shale
# 3                              1              0.074636             Limestone
# 4                              1              1.646640                 Shale
# ...                          ...                   ...                   ...
# 4393                           1              2.247495             Sandstone
# 4394                           1              1.004584          Conglomerate
# 4395                           1              0.721947          Conglomerate
# 4396                           1              1.496427             Sandstone
# 4397                           1              0.256842             Sandstone
#
#      stratigraphic_position  fossil_size  fossil_weight     age
# 0                    Middle        50.65         432.00  43.523
# 1                       Top        48.85         353.29  44.112
# 2                    Bottom        37.66         371.33  43.480
# 3                    Bottom        39.10         232.84  30.228
# 4                       Top        90.84         277.67  67.217
# ...                     ...          ...            ...     ...
# 4393                 Bottom        91.69         415.13  26.606
# 4394                 Bottom        68.97         121.10  44.850
# 4395                 Middle        11.37         288.73  32.186
# 4396                 Bottom       132.34         518.31  59.888
# 4397                    Top         1.70         279.37  40.809
#
# [4398 rows x 13 columns]

# %%
sns.displot(df['uranium_lead_ratio'])

# from the distribution plot we can see that the data is right skewed.
# we have some outliers in the right that means some rare fossils contains high proporsion of uranium_lead_ratio
# most of the fossils contain uranium_lead_ration between 0.4-0.6

# %%
sns.displot(df['carbon_14_ratio'])
# most of the fossils has carbon contians between 0.4-0.6

# %%
sns.displot(df['radioactive_decay_series'])
# most of the fossils have same radioactive_decay series.
# however some fossils have extreme radioactive _decay process.

# %%
sns.displot(df['stratigraphic_layer_depth'])
# most of the fossils found in the depth of between 0-300 meters
# some rare fossils found above 400 of depth may be they are so old fossils

# %%
df['geological_period'].value_counts()
# most of the fossils are formed in the period of Cambrian then Triassic and so on.
# least fossils are formed in the period of Silurian period.
# Out:
# Cambrian         882
# Triassic         676
# Cretaceous       601
# Devonian         498
# Jurassic         490
# Paleogene        405
# Permian          365
# Neogene          311
# Ordovician       100
# Carboniferous     52
# Silurian          18
# Name: geological_period, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['geological_period'])
# here is the count plot of how many fossils formed in each period.
# Out:
# <AxesSubplot:xlabel='geological_period', ylabel='count'>

# %%
df['paleomagnetic_data'].value_counts()
# describes the magnetic field of the earth where the fossils are formed and the magnetic field that fossil present in.
# Out:
# Normal polarity      3160
# Reversed polarity    1238
# Name: paleomagnetic_data, dtype: int64

# %%
sns.countplot(df['paleomagnetic_data'])
# count plot of the magnetic data of the earth to see how it is distributed.
# Out:
# <AxesSubplot:xlabel='paleomagnetic_data', ylabel='count'>

# %%
df['inclusion_of_other_fossils'].value_counts()
# describes how many fossils are contaminated by the other fossils present in that location.
# it is a boolean value.
# Out:
# 1    2727
# 0    1671
# Name: inclusion_of_other_fossils, dtype: int64

# %%
sns.countplot(df['inclusion_of_other_fossils'])
# count plot of the inclussion of other fossils tells how many fossils contains data of other fossils.
# and distributed among themselves.
# Out:
# <AxesSubplot:xlabel='inclusion_of_other_fossils', ylabel='count'>

# %%
sns.displot(df['isotopic_composition'])
# most of the fossils contains the proportion of other isotopes is between 0.5-1.5

# %%
df['surrounding_rock_type'].value_counts()
# it is the count of what kind of rock present around the fossil and which rock help to delay the decay process.
# here we can see that most of the fossils are from sandstone which means these rocks may be helpfull in delaying the process
# of decay.
# Out:
# Sandstone       1497
# Limestone       1166
# Shale           1144
# Conglomerate     591
# Name: surrounding_rock_type, dtype: int64

# %%
sns.countplot(df['surrounding_rock_type'])
# count plot of rock type and no of fossils found in them.
# Out:
# <AxesSubplot:xlabel='surrounding_rock_type', ylabel='count'>

# %%
df['stratigraphic_position'].value_counts()
# where the fossil found in the stratigraphic positions 
# most of the fossils are found in the bottom 
# less no of fossils are found in Top .
# Out:
# Bottom    2667
# Middle    1267
# Top        464
# Name: stratigraphic_position, dtype: int64

# %%
sns.countplot(df['stratigraphic_position'])
# count plot for the positon of the fossils
# Out:
# <AxesSubplot:xlabel='stratigraphic_position', ylabel='count'>

# %%
sns.displot(df['fossil_size'])
# most of the fossil size are in between 50-100

# %%
sns.displot(df['fossil_weight'])
# most of the fossils are below the weight of 600 and some are exception to the graph.

# %%
sns.displot(df['age'])
# most of fossils we got are from around 2000-6000 years old and some of the fosssils are even 10000 years  old also.

# %% [markdown]
# # Bi-variate Analysis

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)

# from this correlation map we can say that most of the columns have linear relationship by the age column
# each column is contributing to tell the age of the fossils we have.
# here we can see that there is no multicollinearity between coloumns as each column speaks about different aspects.
# Out:
# <AxesSubplot:>

# %%
for i in df_num.columns:
    sns.scatterplot(x=df_num[i],y=df['age'])
    plt.show()
# plotting a scatter plot for each numeric column with the target column 'age' to see any trend present between them.
# by seeing the plots we can see that there is a clear pattern between uranium_lead_ration and age and stratigraphic layer_depth.

# %%
for i in df_cat.columns:
    sns.boxplot(x=df_cat[i],y=df['age'])
    plt.show()
    
# plotting box plot between each categoric column with respect to the age column to see there are any insights we can get.
# by seeing at the box plot we can say a lot like which have high propoertion of saying and so on.

# %% [markdown]
# # Study of Outliers and Treatment.

# %%
df_num.columns # looking for the columns to check the outliers.
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %%
sns.boxplot(df['uranium_lead_ratio'])
# Here we can see some outliers presence that the values above 1.2 
# here we can see that there is a cluster of rows above 1.2 and below 1.4 let see how they relate to other columns.
# let's check any relation between these outliers with the other columns
# Out:
# <AxesSubplot:xlabel='uranium_lead_ratio'>

# %%
len(df[df['uranium_lead_ratio']>1.2])/len(df)*100
# Out:
# 0.29558890404729427

# %% [raw]
#  number of outliers for this column is around 0.3%

# %%
df[df['uranium_lead_ratio']>1.2].corr()[:1].T
# Out:
#                             uranium_lead_ratio
# uranium_lead_ratio                    1.000000
# carbon_14_ratio                      -0.160248
# radioactive_decay_series              0.138828
# stratigraphic_layer_depth            -0.367868
# inclusion_of_other_fossils            0.339866
# isotopic_composition                 -0.448109
# fossil_size                          -0.180362
# fossil_weight                        -0.090613
# age                                   0.308044

# %% [raw]
# here we can see that these outliers are correlated with some of the the columns but it is a weak positive and negative
# correlation, let's see how the cluster of rows are correlated.

# %%
df[df['uranium_lead_ratio']>1.2][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 350          Paleogene    Normal polarity                 Shale
# 522           Cambrian  Reversed polarity                 Shale
# 665         Cretaceous  Reversed polarity             Sandstone
# 819           Triassic    Normal polarity             Limestone
# 1054           Neogene    Normal polarity             Sandstone
# 1859          Devonian    Normal polarity             Limestone
# 2672          Cambrian    Normal polarity             Sandstone
# 2863           Permian    Normal polarity                 Shale
# 3314        Ordovician    Normal polarity             Sandstone
# 3399          Jurassic    Normal polarity             Limestone
# 3427           Permian    Normal polarity             Sandstone
# 3881          Triassic  Reversed polarity                 Shale
# 4367          Devonian    Normal polarity                 Shale
#
#      stratigraphic_position
# 350                  Bottom
# 522                  Bottom
# 665                  Bottom
# 819                     Top
# 1054                 Bottom
# 1859                 Bottom
# 2672                 Middle
# 2863                 Middle
# 3314                    Top
# 3399                    Top
# 3427                 Bottom
# 3881                 Middle
# 4367                 Bottom

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
df[(df['uranium_lead_ratio']>1.2)&(df['uranium_lead_ratio']<1.4)].corr()[:1].T
# Out:
#                             uranium_lead_ratio
# uranium_lead_ratio                    1.000000
# carbon_14_ratio                       0.292704
# radioactive_decay_series              0.120860
# stratigraphic_layer_depth             0.514594
# inclusion_of_other_fossils            0.074757
# isotopic_composition                 -0.013345
# fossil_size                           0.093729
# fossil_weight                         0.147100
# age                                   0.558312

# %% [raw]
#   the cluster of rows between 1.2 and 1.4 showing some what strong correlation with other columns
#  it is not an apropriate to treat them to rather include them.

# %%
df[df['uranium_lead_ratio']>1.4] # no need to do analysis for 2 rows.
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 665             1.524921         0.196071                  0.324576
# 3314            1.533270         0.407010                  0.967435
#
#       stratigraphic_layer_depth geological_period paleomagnetic_data  \
# 665                      113.81        Cretaceous  Reversed polarity
# 3314                      54.18        Ordovician    Normal polarity
#
#       inclusion_of_other_fossils  isotopic_composition surrounding_rock_type  \
# 665                            1              0.108539             Sandstone
# 3314                           1              1.176106             Sandstone
#
#      stratigraphic_position  fossil_size  fossil_weight     age
# 665                  Bottom        54.99         261.35  95.549
# 3314                    Top        63.29         270.25  83.034

# %%
sns.boxplot(df_num['carbon_14_ratio'])
# Out:
# <AxesSubplot:xlabel='carbon_14_ratio'>

# %% [raw]
#  there are no outlers in this field

# %%
sns.boxplot(df_num['radioactive_decay_series'])
# Out:
# <AxesSubplot:xlabel='radioactive_decay_series'>

# %% [raw]
#  here we can some outlers on one end
#  and when we observe the outlers we can see 2 clusters of observations below 1.4 is a custer
#  and above 1.4 is another cluster lets see study them more.

# %%
IQR = df['radioactive_decay_series'].quantile(0.75) - df['radioactive_decay_series'].quantile(0.25)
df['radioactive_decay_series'].quantile(0.75)+1.5*IQR # findig UL of Boxplot
# Out:
# 1.3343514951047242

# %%
len(df[df['radioactive_decay_series']>1.33])/len(df)*100
# Out:
# 0.45475216007276037

# %% [raw]
# We have 0.4% of outliers present in the column.

# %%
df[df['radioactive_decay_series']>1.33].corr()[1:2].T
# Out:
#                             carbon_14_ratio
# uranium_lead_ratio                 0.058082
# carbon_14_ratio                    1.000000
# radioactive_decay_series           0.012960
# stratigraphic_layer_depth          0.269808
# inclusion_of_other_fossils        -0.283946
# isotopic_composition              -0.310073
# fossil_size                        0.078460
# fossil_weight                      0.244756
# age                                0.293312

# %% [raw]
#  some columns showing weak correlation with the outliers we have lets see how they perform for the clusters

# %%
df[(df['radioactive_decay_series']>1.33)&(df['radioactive_decay_series']<1.43)].corr()[1:2].T
# Out:
#                             carbon_14_ratio
# uranium_lead_ratio                -0.146832
# carbon_14_ratio                    1.000000
# radioactive_decay_series           0.287589
# stratigraphic_layer_depth          0.338096
# inclusion_of_other_fossils        -0.152052
# isotopic_composition              -0.239003
# fossil_size                       -0.200892
# fossil_weight                     -0.176054
# age                                0.223812

# %% [raw]
#  the first cluster showing weak correlation with other columns with the given outliers let's see how they perform
#  for the second cluster.

# %%
df[df['radioactive_decay_series']>1.33][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 555         Cretaceous  Reversed polarity             Sandstone
# 758          Paleogene  Reversed polarity             Sandstone
# 832           Triassic    Normal polarity             Sandstone
# 1016        Ordovician  Reversed polarity                 Shale
# 1134          Devonian    Normal polarity                 Shale
# 1470          Cambrian    Normal polarity             Limestone
# 1561        Cretaceous  Reversed polarity             Limestone
# 1946           Permian  Reversed polarity             Sandstone
# 2108           Permian  Reversed polarity             Sandstone
# 2259        Ordovician    Normal polarity          Conglomerate
# 2448           Permian    Normal polarity             Limestone
# 2523           Neogene    Normal polarity             Sandstone
# 2589          Devonian  Reversed polarity                 Shale
# 3118           Neogene    Normal polarity             Limestone
# 3159          Cambrian    Normal polarity                 Shale
# 3285          Jurassic  Reversed polarity             Limestone
# 3865          Triassic    Normal polarity             Sandstone
# 3964          Cambrian  Reversed polarity             Sandstone
# 3987          Cambrian    Normal polarity                 Shale
# 4027        Cretaceous    Normal polarity                 Shale
#
#      stratigraphic_position
# 555                  Middle
# 758                  Middle
# 832                     Top
# 1016                 Bottom
# 1134                 Middle
# 1470                 Middle
# 1561                 Bottom
# 1946                 Bottom
# 2108                 Bottom
# 2259                 Bottom
# 2448                 Bottom
# 2523                 Bottom
# 2589                 Middle
# 3118                 Middle
# 3159                 Bottom
# 3285                    Top
# 3865                 Middle
# 3964                 Bottom
# 3987                    Top
# 4027                 Bottom

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
df[df['radioactive_decay_series']>1.43].corr()[1:2].T
# Out:
#                             carbon_14_ratio
# uranium_lead_ratio                 0.353161
# carbon_14_ratio                    1.000000
# radioactive_decay_series           0.162843
# stratigraphic_layer_depth          0.145535
# inclusion_of_other_fossils        -0.478073
# isotopic_composition              -0.528349
# fossil_size                        0.623294
# fossil_weight                      0.685245
# age                                0.370877

# %% [raw]
#  for the second cluster the outlers are have strong correlation with other columns with the given outlers so these
#  outliers are somewhat affecting other columns so removing these or doing outler treatment is not necessary.

# %%
sns.boxplot(df_num['stratigraphic_layer_depth'])
# Out:
# <AxesSubplot:xlabel='stratigraphic_layer_depth'>

# %% [raw]
# here we can see some outliers for this column and we can observe that there are two cluster of rows in the outliers.
# lets see the presence of relation among other columns

# %%
len(df[df['stratigraphic_layer_depth']>400])/len(df)*100
# Out:
# 0.5457025920873124

# %% [raw]
# We have 0.5% of outliers present in this column

# %%
df[df['stratigraphic_layer_depth']>400].corr()[3:4].T
# Out:
#                             stratigraphic_layer_depth
# uranium_lead_ratio                           0.244865
# carbon_14_ratio                             -0.303109
# radioactive_decay_series                     0.353943
# stratigraphic_layer_depth                    1.000000
# inclusion_of_other_fossils                   0.084850
# isotopic_composition                         0.029086
# fossil_size                                 -0.186679
# fossil_weight                                0.305347
# age                                          0.327137

# %% [raw]
# Here we can see some columns have weak correlation with the outliers we have let's see how they perform on clusters

# %%
df[df['stratigraphic_layer_depth']>400][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 16           Paleogene    Normal polarity                 Shale
# 703           Triassic    Normal polarity             Limestone
# 735            Permian    Normal polarity                 Shale
# 1062          Triassic    Normal polarity             Sandstone
# 1084          Cambrian    Normal polarity          Conglomerate
# 1177          Cambrian    Normal polarity                 Shale
# 1386          Silurian    Normal polarity             Limestone
# 1499          Cambrian    Normal polarity             Sandstone
# 1584          Jurassic    Normal polarity             Sandstone
# 1608        Cretaceous    Normal polarity          Conglomerate
# 1787           Neogene    Normal polarity             Sandstone
# 1803          Cambrian    Normal polarity          Conglomerate
# 2023          Jurassic    Normal polarity                 Shale
# 2176          Cambrian    Normal polarity                 Shale
# 2344          Cambrian    Normal polarity             Sandstone
# 2603          Jurassic    Normal polarity             Sandstone
# 2626          Cambrian    Normal polarity             Limestone
# 2732          Jurassic  Reversed polarity             Limestone
# 2822          Devonian  Reversed polarity                 Shale
# 2980        Cretaceous  Reversed polarity             Sandstone
# 3066           Neogene    Normal polarity          Conglomerate
# 3567          Jurassic  Reversed polarity             Limestone
# 3860          Cambrian    Normal polarity             Limestone
# 4397        Cretaceous    Normal polarity             Sandstone
#
#      stratigraphic_position
# 16                   Bottom
# 703                  Middle
# 735                  Bottom
# 1062                 Bottom
# 1084                 Bottom
# 1177                 Bottom
# 1386                 Bottom
# 1499                 Bottom
# 1584                 Bottom
# 1608                 Middle
# 1787                 Bottom
# 1803                 Bottom
# 2023                 Bottom
# 2176                 Bottom
# 2344                 Middle
# 2603                 Bottom
# 2626                 Middle
# 2732                    Top
# 2822                 Bottom
# 2980                 Bottom
# 3066                 Bottom
# 3567                 Bottom
# 3860                 Bottom
# 4397                    Top

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
df[(df['stratigraphic_layer_depth']>400)&(df['stratigraphic_layer_depth']<450)].corr()[3:4].T
# Out:
#                             stratigraphic_layer_depth
# uranium_lead_ratio                           0.163253
# carbon_14_ratio                             -0.051146
# radioactive_decay_series                    -0.350156
# stratigraphic_layer_depth                    1.000000
# inclusion_of_other_fossils                   0.422588
# isotopic_composition                        -0.206513
# fossil_size                                 -0.232956
# fossil_weight                                0.185307
# age                                          0.083897

# %% [raw]
# Here also we didnt see any good correlation score among columns

# %%
len(df[df['stratigraphic_layer_depth']>450])
# Out:
# 4

# %%
df[df['stratigraphic_layer_depth']>450].corr()[3:4].T
# Out:
#                             stratigraphic_layer_depth
# uranium_lead_ratio                           0.404977
# carbon_14_ratio                              0.269062
# radioactive_decay_series                    -0.417711
# stratigraphic_layer_depth                    1.000000
# inclusion_of_other_fossils                  -0.260604
# isotopic_composition                         0.524792
# fossil_size                                  0.417424
# fossil_weight                               -0.314781
# age                                          0.394109

# %% [raw]
# after observing the correlation score only one column have a pretty score regarding our outliers and there are only 4 rows in this section so much of an impact.

# %%
sns.boxplot(df_num['isotopic_composition'])
# Out:
# <AxesSubplot:xlabel='isotopic_composition'>

# %% [raw]
# here we can see some outliers in this column as we observe the point we can see 2 cluster of observation
# lets see any relation present between these outliers and other columns

# %%
IQR = df['isotopic_composition'].quantile(0.75) - df['isotopic_composition'].quantile(0.25)
df['isotopic_composition'].quantile(0.75)+1.5*IQR # findig UL of Boxplot
# Out:
# 2.4229880201766214

# %%
len(df[df['isotopic_composition']>2.42])/len(df)*100
# Out:
# 0.4092769440654843

# %% [raw]
# only 0.4% of outlier we have in this column

# %%
df[df['isotopic_composition']>2.42].corr()[5:6].T
# Out:
#                             isotopic_composition
# uranium_lead_ratio                     -0.229850
# carbon_14_ratio                        -0.033379
# radioactive_decay_series               -0.284013
# stratigraphic_layer_depth              -0.397798
# inclusion_of_other_fossils             -0.238113
# isotopic_composition                    1.000000
# fossil_size                            -0.008536
# fossil_weight                           0.081228
# age                                    -0.322016

# %% [raw]
# Here we can there are no strong correlation with any columns for our outliers lets check with 2 clusters

# %%
df[df['isotopic_composition']>2.42][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 710           Jurassic    Normal polarity                 Shale
# 943         Ordovician    Normal polarity                 Shale
# 1069          Triassic    Normal polarity             Limestone
# 1314        Cretaceous    Normal polarity             Sandstone
# 1668          Cambrian  Reversed polarity             Sandstone
# 1721        Ordovician    Normal polarity             Sandstone
# 1745         Paleogene  Reversed polarity             Sandstone
# 1859          Devonian    Normal polarity             Limestone
# 2239          Triassic  Reversed polarity             Sandstone
# 2245          Cambrian    Normal polarity             Limestone
# 2581         Paleogene    Normal polarity             Sandstone
# 2596          Jurassic    Normal polarity             Sandstone
# 2652          Triassic  Reversed polarity                 Shale
# 2862          Cambrian    Normal polarity             Sandstone
# 2966          Jurassic  Reversed polarity             Sandstone
# 3051          Devonian    Normal polarity             Sandstone
# 3515          Jurassic  Reversed polarity             Limestone
# 4112          Cambrian  Reversed polarity             Sandstone
#
#      stratigraphic_position
# 710                  Middle
# 943                     Top
# 1069                 Bottom
# 1314                 Bottom
# 1668                 Bottom
# 1721                    Top
# 1745                 Middle
# 1859                 Bottom
# 2239                    Top
# 2245                 Middle
# 2581                 Middle
# 2596                    Top
# 2652                 Middle
# 2862                 Bottom
# 2966                 Middle
# 3051                 Middle
# 3515                 Bottom
# 4112                 Bottom

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
len(df[(df['isotopic_composition']>2.42)&(df['isotopic_composition']<2.85)])
# Out:
# 16

# %%
df[(df['isotopic_composition']>2.42)&(df['isotopic_composition']<2.85)].corr()[5:6].T
# Out:
#                             isotopic_composition
# uranium_lead_ratio                     -0.567631
# carbon_14_ratio                        -0.045742
# radioactive_decay_series               -0.659802
# stratigraphic_layer_depth              -0.236492
# inclusion_of_other_fossils              0.003603
# isotopic_composition                    1.000000
# fossil_size                             0.217136
# fossil_weight                           0.229586
# age                                    -0.570313

# %% [raw]
# only the target column have a -0.5 correlation with the outliers here.

# %%
df[df['isotopic_composition']>2.85] # there is no need to analyse these 2 rows
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 2596            0.779682         0.183893                  0.227892
# 2862            0.358741         0.654533                  0.989108
#
#       stratigraphic_layer_depth geological_period paleomagnetic_data  \
# 2596                     138.78          Jurassic    Normal polarity
# 2862                      52.22          Cambrian    Normal polarity
#
#       inclusion_of_other_fossils  isotopic_composition surrounding_rock_type  \
# 2596                           1              2.973047             Sandstone
# 2862                           0              3.071434             Sandstone
#
#      stratigraphic_position  fossil_size  fossil_weight     age
# 2596                    Top        32.68         134.96  44.493
# 2862                 Bottom        57.13         467.16  34.792

# %%
sns.boxplot(df_num['fossil_size'])
# Out:
# <AxesSubplot:xlabel='fossil_size'>

# %% [raw]
# there are outliers in this column while observing we can say that there are 3 clusters we can see lets look for the relation among the columns but we less than 0.3% of rows so let's analyse by 2 clusters

# %%
IQR = df['fossil_size'].quantile(0.75) - df['fossil_size'].quantile(0.25)
df['fossil_size'].quantile(0.75)+1.5*IQR # findig UL of Boxplot
# Out:
# 177.36875

# %%
len(df[df['fossil_size']>177.3])/len(df)*100
# Out:
# 0.34106412005457026

# %% [raw]
# here we have 0.3% of outliers

# %%
df[df['fossil_size']>177.3].corr()[6:7].T
# Out:
#                             fossil_size
# uranium_lead_ratio             0.071593
# carbon_14_ratio                0.125692
# radioactive_decay_series      -0.066120
# stratigraphic_layer_depth     -0.117092
# inclusion_of_other_fossils     0.110916
# isotopic_composition          -0.406653
# fossil_size                    1.000000
# fossil_weight                 -0.110502
# age                            0.134933

# %% [raw]
# here we can see weak correlation between columns and our outliers let's go to the cluster wise

# %%
df[df['fossil_size']>177.3][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 35            Devonian    Normal polarity             Limestone
# 273           Cambrian    Normal polarity             Sandstone
# 326           Cambrian    Normal polarity             Sandstone
# 429           Jurassic    Normal polarity             Limestone
# 644         Cretaceous    Normal polarity                 Shale
# 761           Cambrian    Normal polarity             Limestone
# 1173          Cambrian  Reversed polarity             Limestone
# 1440          Devonian    Normal polarity             Limestone
# 1717           Neogene    Normal polarity             Limestone
# 1751          Jurassic    Normal polarity             Limestone
# 2101          Jurassic    Normal polarity                 Shale
# 2795         Paleogene  Reversed polarity                 Shale
# 3266        Cretaceous  Reversed polarity             Sandstone
# 3505     Carboniferous    Normal polarity             Sandstone
# 3973           Permian    Normal polarity          Conglomerate
#
#      stratigraphic_position
# 35                      Top
# 273                  Bottom
# 326                  Middle
# 429                  Bottom
# 644                  Bottom
# 761                  Middle
# 1173                 Bottom
# 1440                 Bottom
# 1717                 Middle
# 1751                 Bottom
# 2101                 Middle
# 2795                 Bottom
# 3266                 Middle
# 3505                 Bottom
# 3973                 Middle

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
df[(df['fossil_size']>177.3)&(df['fossil_size']<190)].corr()[6:7].T
# Out:
#                             fossil_size
# uranium_lead_ratio             0.358096
# carbon_14_ratio                0.367422
# radioactive_decay_series      -0.119723
# stratigraphic_layer_depth     -0.258163
# inclusion_of_other_fossils     0.210623
# isotopic_composition          -0.004598
# fossil_size                    1.000000
# fossil_weight                 -0.367469
# age                            0.328469

# %%
# no influenting relation between columns here also.

# %%
df[df['fossil_size']>190].corr()[6:7].T
# Out:
#                             fossil_size
# uranium_lead_ratio            -0.218841
# carbon_14_ratio               -0.365259
# radioactive_decay_series      -0.370060
# stratigraphic_layer_depth     -0.264564
# inclusion_of_other_fossils     0.417905
# isotopic_composition          -0.741405
# fossil_size                    1.000000
# fossil_weight                  0.643914
# age                           -0.229297

# %%
# here also no relation found between outliers and the columns so we can safely say that we can do outlier treatment.

# %%
df['fossil_size']=np.where(df['fossil_size']>190,190,df['fossil_size']) # outlier treatment

# %%
sns.boxplot(df_num['fossil_weight'])
# Out:
# <AxesSubplot:xlabel='fossil_weight'>

# %% [raw]
# there we can see a bounch of outliers lets analyse them

# %%
IQR = df['fossil_weight'].quantile(0.75) - df['fossil_weight'].quantile(0.25)
df['fossil_weight'].quantile(0.75)+1.5*IQR # findig UL of Boxplot
# Out:
# 867.22875

# %%
len(df[df['fossil_weight']>867.2])/len(df)*100
# Out:
# 0.43201455206912237

# %% [raw]
# only 0.4% of outliers present in this column

# %%
df[df['fossil_weight']>867.22].corr()[7:8].T
# Out:
#                             fossil_weight
# uranium_lead_ratio               0.178383
# carbon_14_ratio                 -0.172643
# radioactive_decay_series        -0.193031
# stratigraphic_layer_depth       -0.197554
# inclusion_of_other_fossils      -0.155745
# isotopic_composition            -0.082437
# fossil_size                      0.148439
# fossil_weight                    1.000000
# age                              0.131395

# %% [raw]
# no significant relation among the columns

# %%
df[df['fossil_weight']>867.2][['geological_period','paleomagnetic_data','surrounding_rock_type','stratigraphic_position']]
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 314            Permian  Reversed polarity          Conglomerate
# 384          Paleogene    Normal polarity             Sandstone
# 408          Paleogene    Normal polarity             Limestone
# 1314        Cretaceous    Normal polarity             Sandstone
# 1336        Cretaceous  Reversed polarity                 Shale
# 1555          Triassic  Reversed polarity             Sandstone
# 1557          Cambrian  Reversed polarity             Sandstone
# 1599           Permian    Normal polarity             Sandstone
# 1648          Cambrian    Normal polarity             Limestone
# 2027          Jurassic  Reversed polarity             Sandstone
# 3041          Devonian    Normal polarity             Sandstone
# 3087          Cambrian    Normal polarity             Sandstone
# 3374         Paleogene  Reversed polarity                 Shale
# 3621         Paleogene    Normal polarity          Conglomerate
# 3818         Paleogene    Normal polarity             Limestone
# 4095          Devonian  Reversed polarity             Sandstone
# 4168          Devonian    Normal polarity          Conglomerate
# 4231          Cambrian    Normal polarity             Limestone
# 4258           Neogene    Normal polarity             Limestone
#
#      stratigraphic_position
# 314                  Bottom
# 384                  Middle
# 408                  Middle
# 1314                 Bottom
# 1336                    Top
# 1555                    Top
# 1557                 Middle
# 1599                 Bottom
# 1648                 Middle
# 2027                 Middle
# 3041                 Bottom
# 3087                 Bottom
# 3374                 Bottom
# 3621                 Middle
# 3818                 Middle
# 4095                    Top
# 4168                 Bottom
# 4231                 Bottom
# 4258                 Bottom

# %% [raw]
# checking these outliers have any relation with the categoric variables but didn't find any significant relation between them.

# %%
df[(df['fossil_weight']>867.22)&(df['fossil_weight']<920)].corr()[7:8].T
# Out:
#                             fossil_weight
# uranium_lead_ratio              -0.133854
# carbon_14_ratio                 -0.435325
# radioactive_decay_series        -0.164271
# stratigraphic_layer_depth       -0.706212
# inclusion_of_other_fossils      -0.442541
# isotopic_composition             0.387571
# fossil_size                      0.109167
# fossil_weight                    1.000000
# age                             -0.306449

# %%
df[df['fossil_weight']>920].corr()[7:8].T
# Out:
#                             fossil_weight
# uranium_lead_ratio               0.783343
# carbon_14_ratio                  0.077455
# radioactive_decay_series        -0.034118
# stratigraphic_layer_depth       -0.239839
# inclusion_of_other_fossils      -0.175463
# isotopic_composition             0.155008
# fossil_size                      0.474898
# fossil_weight                    1.000000
# age                              0.702324

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %% [raw]
#  we dont do outlier treatment to the target columns so proceeding like this.

# %% [markdown]
# # Encoding the Categorical columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# importing neccessary libraries to convert categoric variables to numeric
# transforming the categoric column into numeric to build machine learning model

# %%
df_cat
# Out:
#      geological_period paleomagnetic_data surrounding_rock_type  \
# 0           Cretaceous    Normal polarity          Conglomerate
# 1             Cambrian    Normal polarity             Limestone
# 2             Cambrian    Normal polarity                 Shale
# 3              Permian    Normal polarity             Limestone
# 4             Devonian    Normal polarity                 Shale
# ...                ...                ...                   ...
# 4393          Jurassic  Reversed polarity             Sandstone
# 4394        Cretaceous  Reversed polarity          Conglomerate
# 4395          Devonian    Normal polarity          Conglomerate
# 4396           Neogene  Reversed polarity             Sandstone
# 4397        Cretaceous    Normal polarity             Sandstone
#
#      stratigraphic_position
# 0                    Middle
# 1                       Top
# 2                    Bottom
# 3                    Bottom
# 4                       Top
# ...                     ...
# 4393                 Bottom
# 4394                 Bottom
# 4395                 Middle
# 4396                 Bottom
# 4397                    Top
#
# [4398 rows x 4 columns]

# %%
df_enc = pd.DataFrame() # using the label encoder converting cat to numeric
for i in df_cat.columns:
    df_enc[i]=le.fit_transform(df_cat[i])

# %%
df_enc
# Out:
#       geological_period  paleomagnetic_data  surrounding_rock_type  \
# 0                     2                   0                      0
# 1                     0                   0                      1
# 2                     0                   0                      3
# 3                     8                   0                      1
# 4                     3                   0                      3
# ...                 ...                 ...                    ...
# 4393                  4                   1                      2
# 4394                  2                   1                      0
# 4395                  3                   0                      0
# 4396                  5                   1                      2
# 4397                  2                   0                      2
#
#       stratigraphic_position
# 0                          1
# 1                          2
# 2                          0
# 3                          0
# 4                          2
# ...                      ...
# 4393                       0
# 4394                       0
# 4395                       1
# 4396                       0
# 4397                       2
#
# [4398 rows x 4 columns]

# %%
df_num1 = df.select_dtypes(include=np.number)
df_num1
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0               0.738061         0.487707                  0.907884
# 1               0.560096         0.341738                  1.121302
# 2               0.424773         0.218493                  0.103855
# 3               0.349958         0.704649                  0.383617
# 4               0.886811         0.777494                  0.593254
# ...                  ...              ...                       ...
# 4393            0.049660         0.601750                  0.762490
# 4394            0.360085         0.215033                  1.002406
# 4395            0.464864         0.553313                  0.659639
# 4396            0.803338         0.272392                  0.123562
# 4397            0.321577         0.348233                  0.265161
#
#       stratigraphic_layer_depth  inclusion_of_other_fossils  \
# 0                         91.17                           0
# 1                        165.44                           0
# 2                        218.98                           1
# 3                         51.09                           1
# 4                        313.72                           1
# ...                         ...                         ...
# 4393                     222.54                           1
# 4394                     276.70                           1
# 4395                      76.77                           1
# 4396                     204.82                           1
# 4397                     436.61                           1
#
#       isotopic_composition  fossil_size  fossil_weight     age
# 0                 0.915951        50.65         432.00  43.523
# 1                 0.803968        48.85         353.29  44.112
# 2                 0.792441        37.66         371.33  43.480
# 3                 0.074636        39.10         232.84  30.228
# 4                 1.646640        90.84         277.67  67.217
# ...                    ...          ...            ...     ...
# 4393              2.247495        91.69         415.13  26.606
# 4394              1.004584        68.97         121.10  44.850
# 4395              0.721947        11.37         288.73  32.186
# 4396              1.496427       132.34         518.31  59.888
# 4397              0.256842         1.70         279.37  40.809
#
# [4398 rows x 9 columns]

# %%
df_final=pd.concat([df_num1,df_enc],axis=1) # combaining all the numeric and encoded columns into one final data Frame.

# %%
df_final
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0               0.738061         0.487707                  0.907884
# 1               0.560096         0.341738                  1.121302
# 2               0.424773         0.218493                  0.103855
# 3               0.349958         0.704649                  0.383617
# 4               0.886811         0.777494                  0.593254
# ...                  ...              ...                       ...
# 4393            0.049660         0.601750                  0.762490
# 4394            0.360085         0.215033                  1.002406
# 4395            0.464864         0.553313                  0.659639
# 4396            0.803338         0.272392                  0.123562
# 4397            0.321577         0.348233                  0.265161
#
#       stratigraphic_layer_depth  inclusion_of_other_fossils  \
# 0                         91.17                           0
# 1                        165.44                           0
# 2                        218.98                           1
# 3                         51.09                           1
# 4                        313.72                           1
# ...                         ...                         ...
# 4393                     222.54                           1
# 4394                     276.70                           1
# 4395                      76.77                           1
# 4396                     204.82                           1
# 4397                     436.61                           1
#
#       isotopic_composition  fossil_size  fossil_weight     age  \
# 0                 0.915951        50.65         432.00  43.523
# 1                 0.803968        48.85         353.29  44.112
# 2                 0.792441        37.66         371.33  43.480
# 3                 0.074636        39.10         232.84  30.228
# 4                 1.646640        90.84         277.67  67.217
# ...                    ...          ...            ...     ...
# 4393              2.247495        91.69         415.13  26.606
# 4394              1.004584        68.97         121.10  44.850
# 4395              0.721947        11.37         288.73  32.186
# 4396              1.496427       132.34         518.31  59.888
# 4397              0.256842         1.70         279.37  40.809
#
#       geological_period  paleomagnetic_data  surrounding_rock_type  \
# 0                     2                   0                      0
# 1                     0                   0                      1
# 2                     0                   0                      3
# 3                     8                   0                      1
# 4                     3                   0                      3
# ...                 ...                 ...                    ...
# 4393                  4                   1                      2
# 4394                  2                   1                      0
# 4395                  3                   0                      0
# 4396                  5                   1                      2
# 4397                  2                   0                      2
#
#       stratigraphic_position
# 0                          1
# 1                          2
# 2                          0
# 3                          0
# 4                          2
# ...                      ...
# 4393                       0
# 4394                       0
# 4395                       1
# 4396                       0
# 4397                       2
#
# [4398 rows x 13 columns]

# %% [markdown]
# # Feature Scaling

# %%
df_scaled = pd.DataFrame()

# %% [raw]
# for feature scaling all the numeric columns should be in a single scale
# # most of the numeric columns dont follow normal distribution we go with MinMaxScaler rather than Standard Scaler.

# %%
print(df['uranium_lead_ratio'].min())
print(df['uranium_lead_ratio'].max()) # here we can see for the column uranium_lead_ratio the min and max values between 0-1.54
# Out:
# 0.0002411924259144
# 1.5332702643937084

# %%
from sklearn.preprocessing import MinMaxScaler # so let's scale them between 0-1
scale = MinMaxScaler(feature_range=(0,1))

df_scaled['uranium_lead_ratio']=pd.DataFrame(scale.fit_transform(df[['uranium_lead_ratio']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio
# count         4398.000000
# mean             0.317474
# std              0.167728
# min              0.000000
# 25%              0.191679
# 50%              0.308849
# 75%              0.429066
# max              1.000000

# %%
print(df['carbon_14_ratio'].min())
print(df['carbon_14_ratio'].max()) #for colum carbon ratio it is already between 0-1 so no need of scaling but lets do to check
# Out:
# 0.0002438505437448
# 0.9999999999

# %%
scale = MinMaxScaler(feature_range=(0,1))

df_scaled['carbon_14_ratio']=pd.DataFrame(scale.fit_transform(df[['carbon_14_ratio']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio
# count         4398.000000      4398.000000
# mean             0.317474         0.429977
# std              0.167728         0.233593
# min              0.000000         0.000000
# 25%              0.191679         0.246085
# 50%              0.308849         0.415903
# 75%              0.429066         0.590652
# max              1.000000         1.000000

# %%
print((df['radioactive_decay_series'].min()))
print(df['radioactive_decay_series'].max())  # the values for this column are less than 0 and to 1.56
# Out:
# 7.56371812158374e-05
# 1.5133254443214954

# %%
scale = MinMaxScaler(feature_range=(0,1)) # scale these values between 0-1.

df_scaled['radioactive_decay_series']=pd.DataFrame(scale.fit_transform(df[['radioactive_decay_series']]))

# %%
 df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series
# count         4398.000000      4398.000000               4398.000000
# mean             0.317474         0.429977                  0.351547
# std              0.167728         0.233593                  0.190272
# min              0.000000         0.000000                  0.000000
# 25%              0.191679         0.246085                  0.209284
# 50%              0.308849         0.415903                  0.338182
# 75%              0.429066         0.590652                  0.478262
# max              1.000000         1.000000                  1.000000

# %%
df_num.columns
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %%
print((df['stratigraphic_layer_depth'].min()))
print(df['stratigraphic_layer_depth'].max()) # the min and max values for these column are 0-495 so
# Out:
# 0.13
# 494.2

# %%
scale = MinMaxScaler(feature_range=(0,10)) # lets scale these values between 0-10 as it contain high values.

df_scaled['stratigraphic_layer_depth']=pd.DataFrame(scale.fit_transform(df[['stratigraphic_layer_depth']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# count         4398.000000      4398.000000               4398.000000
# mean             0.317474         0.429977                  0.351547
# std              0.167728         0.233593                  0.190272
# min              0.000000         0.000000                  0.000000
# 25%              0.191679         0.246085                  0.209284
# 50%              0.308849         0.415903                  0.338182
# 75%              0.429066         0.590652                  0.478262
# max              1.000000         1.000000                  1.000000
#
#        stratigraphic_layer_depth
# count                4398.000000
# mean                    3.090712
# std                     1.746154
# min                     0.000000
# 25%                     1.725666
# 50%                     2.952416
# 75%                     4.286893
# max                    10.000000

# %%
df_num.columns
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %%
print((df['inclusion_of_other_fossils'].min()))
print(df['inclusion_of_other_fossils'].max())
# Out:
# 0
# 1

# %%
print((df['isotopic_composition'].min()))
print(df['isotopic_composition'].max()) # min and max values are 0-3 so lets scale them to 0-1.
# Out:
# 0.0002749630652936
# 3.0714338323637533

# %%
scale = MinMaxScaler(feature_range=(0,1))

df_scaled['isotopic_composition']=pd.DataFrame(scale.fit_transform(df[['isotopic_composition']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# count         4398.000000      4398.000000               4398.000000
# mean             0.317474         0.429977                  0.351547
# std              0.167728         0.233593                  0.190272
# min              0.000000         0.000000                  0.000000
# 25%              0.191679         0.246085                  0.209284
# 50%              0.308849         0.415903                  0.338182
# 75%              0.429066         0.590652                  0.478262
# max              1.000000         1.000000                  1.000000
#
#        stratigraphic_layer_depth  isotopic_composition
# count                4398.000000           4398.000000
# mean                    3.090712              0.305435
# std                     1.746154              0.169852
# min                     0.000000              0.000000
# 25%                     1.725666              0.173630
# 50%                     2.952416              0.294810
# 75%                     4.286893              0.419722
# max                    10.000000              1.000000

# %%
df_num.columns
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %%
print((df['fossil_size'].min()))
print(df['fossil_size'].max()) # these values are high so lets scale them to 0-10
# Out:
# 0.13
# 190.0

# %%
scale = MinMaxScaler(feature_range=(0,10))

df_scaled['fossil_size']=pd.DataFrame(scale.fit_transform(df[['fossil_size']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# count         4398.000000      4398.000000               4398.000000
# mean             0.317474         0.429977                  0.351547
# std              0.167728         0.233593                  0.190272
# min              0.000000         0.000000                  0.000000
# 25%              0.191679         0.246085                  0.209284
# 50%              0.308849         0.415903                  0.338182
# 75%              0.429066         0.590652                  0.478262
# max              1.000000         1.000000                  1.000000
#
#        stratigraphic_layer_depth  isotopic_composition  fossil_size
# count                4398.000000           4398.000000  4398.000000
# mean                    3.090712              0.305435     3.716233
# std                     1.746154              0.169852     1.965047
# min                     0.000000              0.000000     0.000000
# 25%                     1.725666              0.173630     2.230868
# 50%                     2.952416              0.294810     3.615895
# 75%                     4.286893              0.419722     5.072418
# max                    10.000000              1.000000    10.000000

# %%
df_num.columns
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %%
print((df['fossil_weight'].min()))
print(df['fossil_weight'].max()) # these values are in range of 0-1010 so scale them to 0-10
# Out:
# 0.62
# 1010.09

# %%
scale = MinMaxScaler(feature_range=(0,10))

df_scaled['fossil_weight']=pd.DataFrame(scale.fit_transform(df[['fossil_weight']]))

# %%
df_scaled.describe()
# Out:
#        uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# count         4398.000000      4398.000000               4398.000000
# mean             0.317474         0.429977                  0.351547
# std              0.167728         0.233593                  0.190272
# min              0.000000         0.000000                  0.000000
# 25%              0.191679         0.246085                  0.209284
# 50%              0.308849         0.415903                  0.338182
# 75%              0.429066         0.590652                  0.478262
# max              1.000000         1.000000                  1.000000
#
#        stratigraphic_layer_depth  isotopic_composition  fossil_size  \
# count                4398.000000           4398.000000  4398.000000
# mean                    3.090712              0.305435     3.716233
# std                     1.746154              0.169852     1.965047
# min                     0.000000              0.000000     0.000000
# 25%                     1.725666              0.173630     2.230868
# 50%                     2.952416              0.294810     3.615895
# 75%                     4.286893              0.419722     5.072418
# max                    10.000000              1.000000    10.000000
#
#        fossil_weight
# count    4398.000000
# mean        3.229766
# std         1.852778
# min         0.000000
# 25%         1.787349
# 50%         3.047540
# 75%         4.506325
# max        10.000000

# %%
df_num.columns
# Out:
# Index(['uranium_lead_ratio', 'carbon_14_ratio', 'radioactive_decay_series',
#        'stratigraphic_layer_depth', 'inclusion_of_other_fossils',
#        'isotopic_composition', 'fossil_size', 'fossil_weight', 'age'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# import ANN model for regression
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization,Flatten,LeakyReLU
from tensorflow.keras import optimizers,regularizers
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adamax,Nadam
from tensorflow.keras.activations import linear,softplus
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

# %%
df_final
# Out:
#       uranium_lead_ratio  carbon_14_ratio  radioactive_decay_series  \
# 0               0.738061         0.487707                  0.907884
# 1               0.560096         0.341738                  1.121302
# 2               0.424773         0.218493                  0.103855
# 3               0.349958         0.704649                  0.383617
# 4               0.886811         0.777494                  0.593254
# ...                  ...              ...                       ...
# 4393            0.049660         0.601750                  0.762490
# 4394            0.360085         0.215033                  1.002406
# 4395            0.464864         0.553313                  0.659639
# 4396            0.803338         0.272392                  0.123562
# 4397            0.321577         0.348233                  0.265161
#
#       stratigraphic_layer_depth  inclusion_of_other_fossils  \
# 0                         91.17                           0
# 1                        165.44                           0
# 2                        218.98                           1
# 3                         51.09                           1
# 4                        313.72                           1
# ...                         ...                         ...
# 4393                     222.54                           1
# 4394                     276.70                           1
# 4395                      76.77                           1
# 4396                     204.82                           1
# 4397                     436.61                           1
#
#       isotopic_composition  fossil_size  fossil_weight     age  \
# 0                 0.915951        50.65         432.00  43.523
# 1                 0.803968        48.85         353.29  44.112
# 2                 0.792441        37.66         371.33  43.480
# 3                 0.074636        39.10         232.84  30.228
# 4                 1.646640        90.84         277.67  67.217
# ...                    ...          ...            ...     ...
# 4393              2.247495        91.69         415.13  26.606
# 4394              1.004584        68.97         121.10  44.850
# 4395              0.721947        11.37         288.73  32.186
# 4396              1.496427       132.34         518.31  59.888
# 4397              0.256842         1.70         279.37  40.809
#
#       geological_period  paleomagnetic_data  surrounding_rock_type  \
# 0                     2                   0                      0
# 1                     0                   0                      1
# 2                     0                   0                      3
# 3                     8                   0                      1
# 4                     3                   0                      3
# ...                 ...                 ...                    ...
# 4393                  4                   1                      2
# 4394                  2                   1                      0
# 4395                  3                   0                      0
# 4396                  5                   1                      2
# 4397                  2                   0                      2
#
#       stratigraphic_position
# 0                          1
# 1                          2
# 2                          0
# 3                          0
# 4                          2
# ...                      ...
# 4393                       0
# 4394                       0
# 4395                       1
# 4396                       0
# 4397                       2
#
# [4398 rows x 13 columns]

# %%
x=df_final.drop(columns='age')
y=df_final['age']

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.15)

# %%
x.shape
# Out:
# (4398, 12)

# %%
reg_model = Sequential()

# adding hidden layers
reg_model.add(Dense(32,input_dim=12,activation='relu'))
reg_model.add(Dropout(0.4))
reg_model.add(BatchNormalization())
reg_model.add(Dense(1,activation='linear'))

# initialize Activation funtion
adam = optimizers.Adam()
reg_model.compile(optimizer='rmsprop',loss='mape')

# check for summary of model
reg_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 577 (2.25 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
 reg_model.fit(xtrain,ytrain,epochs=24,batch_size=15,validation_split=0.15)
# Out:
# Epoch 1/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 98.2848 - val_loss: 91.0711
# Epoch 2/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 87.4952 - val_loss: 74.6034
# Epoch 3/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 71.0534 - val_loss: 55.1410
# Epoch 4/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 52.0649 - val_loss: 39.7753
# Epoch 5/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 37.1798 - val_loss: 34.8687
# Epoch 6/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 34.4027 - val_loss: 34.1607
# Epoch 7/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 33.4131 - val_loss: 33.9544
# Epoch 8/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 32.5696 - val_loss: 33.8536
# Epoch 9/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 31.9837 - val_loss: 33.6713
# Epoch 10/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.2206 - val_loss: 33.4598
# Epoch 11/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 33.0224 - val_loss: 33.4504
# Epoch 12/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.9815 - val_loss: 33.4461
# Epoch 13/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.8691 - val_loss: 33.4620
# Epoch 14/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2312 - val_loss: 33.2147
# Epoch 15/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.0789 - val_loss: 33.2395
# Epoch 16/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 33.7219 - val_loss: 33.1328
# Epoch 17/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7613 - val_loss: 32.7626
# Epoch 18/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 31.7418 - val_loss: 32.9166
# Epoch 19/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 31.2798 - val_loss: 30.6218
# Epoch 20/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 29.3250 - val_loss: 29.9172
# Epoch 21/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 27.2425 - val_loss: 26.2659
# Epoch 22/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 26.6332 - val_loss: 23.8398
# Epoch 23/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 25.7360 - val_loss: 26.0752
# Epoch 24/24
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 24.4898 - val_loss: 22.4642

# %%
loss = reg_model.evaluate(xtest, ytest)
print(f'Test Loss: {loss}')
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 22.7511
# Test Loss: 22.402048110961914

# %%
x1=pd.concat([df_scaled,df_enc],axis=1)
y1=df_final['age']

x1train,x1test,y1train,y1test=train_test_split(x1,y1,test_size=0.15)

# %%
x1.shape
# Out:
# (4398, 11)

# %%
reg_model2 = Sequential()

# adding hidden layers
reg_model2.add(Dense(64,input_dim=11,activation='relu'))
reg_model2.add(Dropout(0.4))
reg_model2.add(BatchNormalization())
reg_model2.add(Dense(1,activation='linear'))
# initialize Activation funtion
reg_model2.compile(optimizer='rmsprop',loss='mape')

# check for summary of model
reg_model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,089 (4.25 KB)
#  Trainable params: 961 (3.75 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
 reg_model2.fit(x1train,y1train,epochs=24,batch_size=15,validation_split=0.2)
# Out:
# Epoch 1/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 97.3304 - val_loss: 87.9836
# Epoch 2/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 81.4830 - val_loss: 61.2507
# Epoch 3/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 59.5842 - val_loss: 41.3690
# Epoch 4/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.7919 - val_loss: 35.8860
# Epoch 5/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 34.0366 - val_loss: 33.1370
# Epoch 6/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 31.6165 - val_loss: 31.0773
# Epoch 7/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 31.1129 - val_loss: 28.8527
# Epoch 8/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 28.3099 - val_loss: 25.6238
# Epoch 9/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 24.3373 - val_loss: 21.1769
# Epoch 10/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 19.0897 - val_loss: 13.0047
# Epoch 11/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 15.9394 - val_loss: 9.7601
# Epoch 12/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 14.3820 - val_loss: 9.5963
# Epoch 13/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 14.0041 - val_loss: 6.8670
# Epoch 14/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 13.9769 - val_loss: 8.9421
# Epoch 15/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.0029 - val_loss: 7.5461
# Epoch 16/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 13.0907 - val_loss: 6.8575
# Epoch 17/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.8065 - val_loss: 7.7580
# Epoch 18/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.7745 - val_loss: 6.5392
# Epoch 19/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.6378 - val_loss: 6.5542
# Epoch 20/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.7289 - val_loss: 6.6986
# Epoch 21/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 12.6085 - val_loss: 6.7889
# Epoch 22/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 12.8602 - val_loss: 5.6279
# Epoch 23/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.6840 - val_loss: 6.6313
# Epoch 24/24
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 12.9019 - val_loss: 6.1164

# %%
loss = reg_model2.evaluate(x1test, y1test)
print(f'Test Loss: {loss}')
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 5.9982
# Test Loss: 6.196104526519775
